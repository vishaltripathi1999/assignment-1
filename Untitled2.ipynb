# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('velocity_car.csv', header=None)
print(data)

fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(data.corr(), center=0, cmap='Blues')
ax.set_title('HeatMap')

fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(data.corr(), center=0, cmap='BrBG', annot=True)
ax.set_title('HeatMap')
# Out:
#                0           1          2
# 0    -181.335322   80.539863   1.500000
# 1    -181.338654   79.538781   1.600109
# 2    -181.341885   78.535024   1.700485
# 3    -181.345013   77.528627   1.801125
# 4    -181.348040   76.519622   1.902026
# ...          ...         ...        ...
# 1719  314.679857 -592.940122  22.222222
# 1720  315.716359 -592.874364  22.222222
# 1721  316.756341 -592.817879  22.222222
# 1722  317.799831 -592.770746  22.222222
# 1723  318.846861 -592.733047  22.222222
#
# [1724 rows x 3 columns]
# Text(0.5, 1.0, 'HeatMap')
